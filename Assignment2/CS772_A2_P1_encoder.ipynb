# %% [markdown]
# # Libraries

# %%
import nltk
from nltk.corpus import brown, stopwords
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from nltk.tokenize import word_tokenize
import time
import seaborn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data

# %% [markdown]
# ## Downloading data

# %%
nltk.download("brown")
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("universal_tagset")
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# True

# %% [markdown]
# ## Exploring the corpus

# %%
brown_words =  brown.tagged_words(tagset="universal")
brown_sentences = brown.tagged_sents(tagset="universal")

# %%
brown_words
# Out:
# [('The', 'DET'), ('Fulton', 'NOUN'), ...]

# %%
len(brown_words)
# Out:
# 1161192

# %%
brown_sentences[0]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP'),
#  ("Atlanta's", 'NOUN'),
#  ('recent', 'ADJ'),
#  ('primary', 'NOUN'),
#  ('election', 'NOUN'),
#  ('produced', 'VERB'),
#  ('``', '.'),
#  ('no', 'DET'),
#  ('evidence', 'NOUN'),
#  ("''", '.'),
#  ('that', 'ADP'),
#  ('any', 'DET'),
#  ('irregularities', 'NOUN'),
#  ('took', 'VERB'),
#  ('place', 'NOUN'),
#  ('.', '.')]

# %%
len(brown_sentences)
# Out:
# 57340

# %% [markdown]
# Now, let us check whether *brown_words* and *brown_sentences* have the same (word,tag) pairs.

# %%
brown_sent2words = []
for sent in  brown_sentences:
  for word_tag in sent:
    brown_sent2words.append(word_tag)

# %%
print(len(brown_words) - len(brown_sent2words))
# Out:
# 0

# %% [markdown]
# The number of (word,tag) pairs are the same in both

# %%
i = 0
while(i != len(brown_words)):
  if(brown_words[i] != brown_sent2words[i]):
    print(brown_words[i], brown_sent2words[i])
  i += 1

# %% [markdown]
# This means that the (word,tag) pairs in the two are the same.

# %% [markdown]
# ### Tags in the tagset

# %%
unique_tags = []

for sent in brown_sentences:
  for (word, tag) in sent:
    if(tag not in unique_tags):
      unique_tags.append(tag)

# %%
print(unique_tags)
# Out:
# ['DET', 'NOUN', 'ADJ', 'VERB', 'ADP', '.', 'ADV', 'CONJ', 'PRT', 'PRON', 'NUM', 'X']

# %%
print(len(unique_tags))
# Out:
# 12

# %% [markdown]
# ## Data Preprocessing

# %%
max_len_sentence = 0
for sent in brown_sentences:
  max_len_sentence = max(max_len_sentence, len(sent))

# %%
print(max_len_sentence)
# Out:
# 180

# %%
n = 0
for sent in brown_sentences:
  if(len(sent) >= 100):
    n += 1

# %%
print(n)
# Out:
# 40

# %% [markdown]
# The max. length of any sentence in the data is 180, and the number of sentences with length >= 100 is just 40.
#
# So let us choose the standardizing length to be 100.

# %%
STD_LEN = 100

# %%
words = []
tags = []

for sent in brown_sentences:
  words.append([])
  tags.append([])
  for (word, tag) in sent:
    words[-1].append(word.lower())
    tags[-1].append(tag)

# %%
print(words[:4])
# Out:
# [['the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', "atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['the', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'city', 'executive', 'committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'city', 'of', 'atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ['the', 'september-october', 'term', 'jury', 'had', 'been', 'charged', 'by', 'fulton', 'superior', 'court', 'judge', 'durwood', 'pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'mayor-nominate', 'ivan', 'allen', 'jr.', '.'], ['``', 'only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.']]

# %% [markdown]
# Splitting data into train:test ratio of 90:10

# %%
train_words = words[:len(words)*9//10]
train_tags = tags[:len(tags)*9//10]

test_words = words[len(words)*9//10:]
test_tags = tags[len(words)*9//10:]

# %% [markdown]
# ### Giving ids to the data

# %%
word2id = {}

for i in range(len(words)):
  for word in words[i]:
    if(word not in word2id):
      word2id[word] = len(word2id)

tag2id = {}

for i in range(len(tags)):
  for tag in tags[i]:
    if(tag not in tag2id):
      tag2id[tag] = len(tag2id)

# %%
print(len(word2id))
# Out:
# 49815

# %%
print(len(tag2id))
# Out:
# 12

# %%
# Setup GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
train_x = []
train_y = []

for (w, t) in zip(train_words, train_tags):
  x = [word2id[word] for word in w]
  y = [tag2id[tag] for tag in t]

  x = torch.from_numpy(np.array(x)).to(device)
  y = torch.from_numpy(np.array(y)).to(device)

  train_x.append(x)
  train_y.append(y)

# %%
test_x = []
test_y = []

for (w, t) in zip(test_words, test_tags):
  x = [word2id[word] for word in w]
  y = [tag2id[tag] for tag in t]

  x = torch.from_numpy(np.array(x)).to(device)
  y = torch.from_numpy(np.array(y)).to(device)

  test_x.append(x)
  test_y.append(y)

# %% [markdown]
# 5-fold cross validation has to be done splitting the training data into 5 almost equal parts

# %%
train_valid_x = []
train_valid_y = []
m = len(train_x)

for i in range(5):
  part_x = train_x[i*m//5:(i+1)*m//5]
  part_y = train_y[i*m//5:(i+1)*m//5]

  train_valid_x.append(part_x)
  train_valid_y.append(part_y)

# %% [markdown]
# # Model

# %%
class POStagger(nn.Module):

  def __init__(self, vocab_size, target_size, embedding_dim, hidden_state_dim):
    super(POStagger, self).__init__()

    self.vocab_size = vocab_size
    self.target_size = target_size
    self.embedding_dim = embedding_dim
    self.hidden_state_dim = hidden_state_dim

    self.embeddings = nn.Embedding(vocab_size, embedding_dim)

    self.lstm = nn.LSTM(embedding_dim, hidden_state_dim)

    self.output = nn.Linear(hidden_state_dim, target_size)

    self.hidden_state = self.hidden_state_initialize()

  def hidden_state_initialize(self):
    return (torch.zeros(1, 1, self.hidden_state_dim).to(device), torch.zeros(1, 1, self.hidden_state_dim).to(device))

  def forward(self, input):
    embeddings = self.embeddings(input)

    lstm_output, self.hidden_state = self.lstm(embeddings.view(len(input), 1, -1), self.hidden_state)

    output = self.output(lstm_output.view(len(input), -1))

    probs = F.log_softmax(output, dim=1)

    return probs

# %%
EMBEDDING_DIM = 128
HIDDEN_STATE_DIM = 128

model = POStagger(len(word2id), len(tag2id), EMBEDDING_DIM, HIDDEN_STATE_DIM).to(device)

criterion = nn.NLLLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.3)
optimizer = optim.Adam(model.parameters())

# %% [markdown]
# # Training

# %%
def weight_initialize(model):
  for _, parameters in model.named_parameters():
    nn.init.uniform_(parameters.data, -1, 1)

model.apply(weight_initialize)
# Out:
# POStagger(
#   (embeddings): Embedding(49815, 128)
#   (lstm): LSTM(128, 128)
#   (output): Linear(in_features=128, out_features=12, bias=True)
# )

# %%
# def train(model, X, y, optimizer, criterion):

#   model.train()

#   model.hidden_state_initialize()

#   # total_loss = 0

#   # for (X, y) in zip(X_loader, y_loader):
#     # X = torch.reshape(X, X.size()[1:])
#     # y = torch.reshape(y, y.size()[1:])

#   model.zero_grad()

#   probs = model(X)

#   loss = criterion(probs, y)
#   loss.backward()
#   # total_loss += loss.item()

#   optimizer.step()

#   return loss.item()

# %%
# def evaluate(model, X, y, criterion):

#   model.eval()

#   # total_loss = 0

#   # for (X, y) in zip(X_loader, y_loader):
#     # X = torch.reshape(X, X.size()[1:])
#     # y = torch.reshape(y, y.size()[1:])

#   probs = model(X)

#   loss = criterion(probs, y)
#   # total_loss += loss.item()

#   return loss.item()

# %%
EPOCHS = 20

for epoch in range(EPOCHS):
  tic = time.time()

  epoch_training_loss = 0.0
  epoch_validation_loss = 0.0

  r = np.random.randint(5)
  for i in range(5):
    if(i != r):
      # for (xs, ys) in zip(train_valid_x[i], train_valid_y[i]):
      #   train_loss = train(model, xs, ys, optimizer, criterion)
      model.train()

      for (xs, ys) in zip(train_valid_x[i], train_valid_y[i]):
        print(xs)
        model.zero_grad()

        model.hidden_state = model.hidden_state_initialize()

        probs = model(xs)

        loss = criterion(probs, ys)
        epoch_training_loss += loss.item()
        loss.backward()

        optimizer.step()

  # valid_loss = evaluate(model, xs, ys, criterion)
  model.eval()
  for (xs, ys) in zip(train_valid_x[r], train_valid_y[r]):
    with torch.no_grad():
      model.hidden_state = model.hidden_state_initialize()

      probs = model(xs)

      loss = criterion(probs, ys)
      epoch_validation_loss += loss.item()

  toc = time.time()

  epoch_time = toc - tic
  epoch_min = epoch_time // 60
  epoch_sec = epoch_time % 60

  torch.save(model.state_dict(), "model%d" % (epoch+1))

  print(f"Epoch : {epoch+1} -- Training loss : {epoch_training_loss/len(train_words)},\t Validation loss : {epoch_validation_loss/len(train_words)},\t Time : {epoch_min}m {epoch_sec}s")

  # torch.save(model.state_dict(), "model%d" % (epoch+1))
  # print(f"Epoch : {epoch+1} -- training loss : {epoch_training_loss/len(train_words)}, validation loss : {epoch_validation_loss/len(train_words)}" )
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor([   15,  2995,  8933,   127, 37495,  5717,   118,   104,     0,  2541,
#           456, 14366,     0, 23858,    18,    24], device='cuda:0')
# tensor([20996,  2250, 29069,  2797,   168,     0, 27394,    32, 46835, 46836,
#            24], device='cuda:0')
# tensor([   15,  2939,  4433,  5788, 46008,   440,     0, 19890,    32,  3594,
#            18,    32,   397,  2681, 18059,    32,  1885,    50,     0, 13673,
#          3259,  2044,  4116,  2946,    24], device='cuda:0')
# tensor([   15,   697,   934,  2939,   191,   127,   440,   104,   418,    50,
#         34422,    18,    24], device='cuda:0')
# tensor([ 456,    9,    0, 2924,    9,  335, 2462,   32,  397, 1212,  698,  335,
#         9766, 8254, 3274,   56, 4741,   24], device='cuda:0')
# tensor([  482,  3594,    34,    67,  2507,    56,  2167,    32, 20996,  5114,
#           335,   714,  5016,   859,   335,  6073, 46837,  3849,    24],
#        device='cuda:0')
# tensor([  648,    16,  9198,   375, 12148,  1243,    32,    78,  4005,  5777,
#          2586,    34,     0,  4425,     9,   572,  2243, 46838,    39,   374,
#         32349,    24], device='cuda:0')
# tensor([ 2394, 15939,     0,  6285,    39,  7197, 20110,    39,  5788,   476,
#          2134,   620,    24], device='cuda:0')
# tensor([ 1028,   199,   476,  1382,    56,  9105,    67, 41122,  3443,    32,
#            78,  2484,  6037,   102,    56,  3419,    26,    39, 23278,   894,
#          5018,  1060,    20,  4904,  1469,   572,   606,   102,    24],
#        device='cuda:0')
# tensor([   15, 46839,   127, 46840,  6660,    26,   213,   244,   901,  2704,
#           964,   168,   191,    18,    32, 36872,   884,    32, 18203,  1793,
#             0,  3423,   141,   199, 16649,   894, 10165,    24],
#        device='cuda:0')
# tensor([  277,   476,    16,   206,   375,  1425,    88,   866, 16518,    26,
#         46841,    32,   274, 11709,     0,  9345,  6047, 43104,    32,   191,
#         17555,    42,     0,  2198,     9,  8662, 12946,    39,  3954,    24],
#        device='cuda:0')
# tensor([ 5364,    66, 12778,    24], device='cuda:0')
# tensor([  15,  145,  179, 1953,    9,    0, 3423,   32,   39, 2995,  145,    0,
#          105,   18,   32,  397,  121,   24], device='cuda:0')
# tensor([   15,   901,   902,  5738, 46842,   711,    67, 29811,   482,   902,
#          2449,    26,    18,    24], device='cuda:0')
# tensor([46843,  3081,    44, 11846,    24], device='cuda:0')
# tensor([  15,  902,  217,    0, 3034,   24], device='cuda:0')
# tensor([1507,  191,  723,  286,   32, 6155,   18,   24], device='cuda:0')
# tensor([12009,    32,   199,    22,  2048, 13942,     9,     0,  2058, 13122,
#            39, 18987, 18637,     0,  9617,    24], device='cuda:0')
# tensor([ 4462,  3073,   124,  1199,  1060,   142,    39,   335, 10903,  1818,
#            44,   817,    56, 22328,    24], device='cuda:0')
# tensor([ 5284,    79,   805,    56,   701, 16411,    19,   199,   203,  2620,
#            56,   883, 46844, 46842,   163, 18843,    32,  1532,   476,   397,
#            56,  1916,     0, 15275,    24], device='cuda:0')
# tensor([  397, 16816,   456,     9,     0, 12946,  6492,   193,   335,  2113,
#         46845,    32,    39,  3482, 40570,    42,     0,  6550, 19396,    32,
#             0,   665,    23,     9,    20, 14596,   104,    78,  1953,     9,
#             0,  3423,    24], device='cuda:0')
# tensor([    0,  6550,    44,     7,   275,   309,    32,  7437, 16292,   104,
#         45402,    26,  3978,    32,   193,   714,  8872,     9,  3011,   146,
#          2623,   440,    56,     0, 14310,    24], device='cuda:0')
# tensor([ 1940,   226, 46846, 30269,     0, 11825,  8875, 29872,   697,    67,
#         46847, 13891,    56,     0,  5366,  8576,     9,     0, 46848,    24],
#        device='cuda:0')
# tensor([ 4462,  3937,   440,     0,   146,  1038,    56,     0, 24342, 14310,
#            24], device='cuda:0')
# tensor([    0,  3978,  9948,     9,     0,    23,   476,   714,    39,  5679,
#            32,  9092,  2925,    56,     0,  1824,    39, 24497,     7,  8216,
#           793,  3050,     9,     0,  5022,    24], device='cuda:0')
# tensor([ 5258,    42,     0, 46849,    32, 36872, 12366, 46850,   190,     0,
#         11087, 12248,    32,    39,  5284, 46851,   656,    24],
#        device='cuda:0')
# tensor([ 5748, 11846,   141,    67, 46852,    32,   397, 10985,    56,  8044,
#           335, 30711,    24], device='cuda:0')
# tensor([  612,   191, 11229,    32, 46842,    44,  2009,    32,  2212, 14521,
#           772,    56,     0,  2307,    39,  1659,   163, 46853,    19,    79,
#           805,  3646,   397,    44, 43125,    56,  7894,  5279,    88,  2374,
#           620,   701,    24], device='cuda:0')
# tensor([12174, 15876, 12732,   190,  4462,    24], device='cuda:0')
# tensor([  397, 11705,   817,     0, 21813,    56,  4121,    26,    39, 14966,
#             0,  2788, 46623,   104,     0,  5738,    24], device='cuda:0')
# tensor([ 9092,     0, 14310, 12958,  3125,  3050,     9,     0,   244,  9948,
#            32,   397, 27790, 32353,     0,  5993,  3423,  5668,    24],
#        device='cuda:0')
# tensor([ 6155,    44,  7540,    26, 11922,    24], device='cuda:0')
# tensor([46854,     7, 32529,    32,  4462, 21231,    56,     0, 11087,   146,
#            39,  3937,   817,    24], device='cuda:0')
# tensor([ 141, 5011,   34,   79,   32,  397,   34,  274, 2705, 3265, 2935,   26,
#            0, 3423,  482, 5364, 3721,   24], device='cuda:0')
# tensor([   15,   550,  5011,    32, 36872,    18,  1453,  1453],
#        device='cuda:0')
# tensor([  397,     5, 25039,    24], device='cuda:0')
# tensor([4462,  664, 9068,   24], device='cuda:0')
# tensor([   15,  2704,   277,    18,    32,   397,   737,   456, 33238,    32,
#         12920,   335,  1738,  6874,    24], device='cuda:0')
# tensor([32069,   335, 23293,  5639,  2044,    32,  5364, 12366,  9068, 11171,
#           168,     0,  6550,    39,  2630,    19,  1499,   193, 36872,   168,
#           335,  1953,    24], device='cuda:0')
# tensor([ 9496,     0,   146, 19809,    32,   199,  3364,     0,   418,    39,
#          3482,    42,     0,  7011,    24], device='cuda:0')
# tensor([5364, 1465,  190,  484,   24], device='cuda:0')
# tensor([1382, 1940,  701, 5454,   32, 4462, 2629,  168, 2031,   39, 8878,  124,
#          146, 2009,   24], device='cuda:0')
# tensor([  335,  3551, 19024,    24], device='cuda:0')
# tensor([  648,   489,  2756,  1909,     0,    23,    34,  2585,    67,  3502,
#             9,  3435, 46855,    32,   193, 46844, 46842,    67,  5555,  3952,
#            32,    79,    44,   879,   141, 46856,    39,  9355,   141,     0,
#           633,   482, 29975,    24], device='cuda:0')
# tensor([46842,   772,    44,  7540,    56,   127,   187,    24],
#        device='cuda:0')
# tensor([   67,   373,  3971,     0, 23548,  4474,   620, 16929,    26,   226,
#          1939,    32,    39,  1049, 36631,   168,   179,     9,     0,  9025,
#          9836,    24], device='cuda:0')
# tensor([  124,  2394, 30733,   193,   894, 10096,   372,   168,     0,    99,
#             9,     0,   244,    32,   648,     0, 46857, 44820, 42946, 10876,
#            67,  6588,    24], device='cuda:0')
# tensor([ 2943,     0,  2367,   859,    32,  6155,  2630, 16305,    42,     0,
#          8584,     9,     0,    23,    24], device='cuda:0')
# tensor([   15,   536, 45829, 29707,    18,  1453,  1453], device='cuda:0')
# tensor([   79,    44,     0, 46858,    24], device='cuda:0')
# tensor([ 7292,    32,  5364,  2575,    56,  8179,   701, 11800,    24],
#        device='cuda:0')
# tensor([ 397,   80,  274, 2167,   32, 1742,  104,  557,    0,  392,   24],
#        device='cuda:0')
# tensor([  206,  2612,   375,     0, 10012,    32, 46859,   373,    26,     0,
#          4684,    32, 36872,  2629, 46860,    32,    67,  2591,   104,   335,
#           789, 24329,    24], device='cuda:0')
# tensor([    0, 44820, 11097,    78,  2155,   193,  2666,  3551,    39,  1143,
#           397,   471,    16,  1687,     9,    79,    24], device='cuda:0')
# tensor([397,   5,  16, 374,  24], device='cuda:0')
# tensor([   67,  5782,   609,    26,   392,     9,     0,   244,    32,  2623,
#           557,     7, 46861,    24], device='cuda:0')
# tensor([5364, 4461,  238,   79,   24], device='cuda:0')
# tensor([2511, 3797,   32,  930,   42, 5896,   32,  609,  607,  104, 2728, 1953,
#           24], device='cuda:0')
# tensor([ 191,    0, 4076,  476, 2732,  168,   78, 1841, 1183,  179,   32,   39,
#           79,   44,  557,   78,   19, 6155,  552,  335, 1499,  193, 4462, 1304,
#          168,  335, 8495,   24], device='cuda:0')
# tensor([   0, 7011,   44, 7741,   24], device='cuda:0')
# tensor([   67,  3812,  4798,   552,    79,  2056,  2732,    32, 19448,    24],
#        device='cuda:0')
# tensor([ 5364,   725, 46844, 46842, 25204,  2942,    32,    67, 46862, 24245,
#         46863,   141,   901,    56,  8562,    24], device='cuda:0')
# tensor([ 4462, 21231,   190,    56,  4620,    79, 34792,   656,    24],
#        device='cuda:0')
# tensor([  193,    67, 28519, 46842, 43050,   168,   701,    24],
#        device='cuda:0')
# tensor([  185,   397,    44,   374,   375, 46864,    32,    39,   335, 25429,
#           476, 27540,    24], device='cuda:0')
# tensor([36872, 43330,    67,  3812,  5417, 46865,    19,  1034, 46844, 46866,
#         12434,    39, 26548,   817,   193,    67, 29889, 46867,    24],
#        device='cuda:0')
# tensor([  397,  2630,    56,  3079,   440,    32, 22322, 13631,    24],
#        device='cuda:0')
# tensor([ 4462,  2006,   701,    67, 24688, 15871,    19,  5901,   701,   859,
#          3832,   104,   335, 12695,    24], device='cuda:0')
# tensor([33564,    32, 36872,  9557,    67, 13459,  4777,    26,     0,  2511,
#             9,   335,   392,    32, 13613,   701, 28504,    24],
#        device='cuda:0')
# tensor([   15, 28517,    32,  6155,    24], device='cuda:0')
# tensor([ 4850,  8399,   335, 27380,    18,    32,   397,  4762,    24],
#        device='cuda:0')
# tensor([  15,  577,  190,  335,  915,   32,  218,  902, 1453, 1453],
#        device='cuda:0')
# tensor([ 901,  209,   95,   56, 2939,  145,  701, 1728,   39,  698,  550, 2704,
#          552,    9,   18, 3260, 3260], device='cuda:0')
# tensor([40768, 28219,    32,  5364,  3257, 12776,   404, 12776,  2009,   456,
#          1060,  8599,    67,  1814,    24], device='cuda:0')
# tensor([36872,  7533,    78,   193, 36497,  3551,    32,   335,  2816,  2620,
#         23689,    50,     0,  8262,    24], device='cuda:0')
# tensor([ 6155,    44, 45723,   859,     0,   665, 15569, 12776,   266,  4462,
#         41131,  6929,    39, 43050,   557, 46868,  9700,    32,    33,    34,
#          5901, 46869,  2935,  3981,   266,   397,   484,  5700,    24],
#        device='cuda:0')
# tensor([36872,   737,    79,    24], device='cuda:0')
# tensor([22265,   440,    32,   335,  3551,  7149,    32,   397,   426,   456,
#             0,  9488, 10111,    24], device='cuda:0')
# tensor([  15, 3259,  168,   78,   18, 3260, 3260], device='cuda:0')
# tensor([ 2009,     0,  6803,    32, 10431,  1940,     0, 24184, 46870,    32,
#          1212,   127,   187,  6073,    32, 26805, 46871,     9,  7512,    24],
#        device='cuda:0')
# tensor([46868, 24399, 46872,    42,   335, 27304,    34,    48,   236,    24],
#        device='cuda:0')
# tensor([   15,    50, 46789,    32,  6155,  3260,  3260], device='cuda:0')
# tensor([  902,   476,  1113,    18,    32,  4462,  5012,    32,  8583,     0,
#          4917,  1042,   456,     9, 46868,  9700,    24], device='cuda:0')
# tensor([   15,    19,   136,    32,   901,   209,   641,   127,  4105,    78,
#           136, 46873,   197,    18,   475], device='cuda:0')
# tensor([ 5364, 33998,    24], device='cuda:0')
# tensor([  15,  536, 2375,  406,  397,  987,   79, 1453, 1453], device='cuda:0')
# tensor([ 2110,   550, 10468,   737,   277,    32, 36872,    24],
#        device='cuda:0')
# tensor([209, 641, 784, 998,  18,  24], device='cuda:0')
# tensor([ 4462,  3937,   190,     0,  1042,    39,  1293,     7,   912,    79,
#            44,  1439,  3646,    20, 46874,   406,  2079,    50,  5721,    24],
#        device='cuda:0')
# tensor([ 5364, 12778,    24], device='cuda:0')
# tensor([   15,  1507,  2063,    67,  2420,     9,   550, 46875,    34,    18,
#            32,   397,   884,    24], device='cuda:0')
# tensor([   15,   209,  2421, 26916,  1217,   213,   475,    39, 46842,   487,
#            95,  4331,    67,  1907,   843,   411,    19,  1364,   104,    18,
#            24], device='cuda:0')
# tensor([ 8736,     0,   197,   859,    32,  4462,  4731,   335,  3627,   104,
#           335, 46876,   141,   901, 28883,   772,     9,   679, 34916,    24],
#        device='cuda:0')
# tensor([  335, 15281,   168, 46844, 46842,    44, 46877,    24],
#        device='cuda:0')
# tensor([  15, 2952,  209,  987,  456,    9,  964,   18, 1453, 1453],
#        device='cuda:0')
# tensor([3017,    0, 9025, 1576,   32,  199, 4461,  392,  190,    0, 6550,    0,
#         1499,  199,   34, 2079,   24], device='cuda:0')
# tensor([45769,  2760,  1876,   102,    26,     0,   244,    32,   185,   277,
#            44,    16,  1880,    56,  8773,   102,    24], device='cuda:0')
# tensor([29286,    26,     0,  1575,  7011,    56, 15281,  1940,   701,    32,
#          5364,  2250,   335, 11706,   463,    39, 12002,   456,    24],
#        device='cuda:0')
# tensor([  397,    39, 36872, 17561,   817,     0,  1265,   146,    56,     0,
#          3423,    24], device='cuda:0')
# tensor([ 2566,  2681, 14221,   199,  3364,   894,  4706,    24],
#        device='cuda:0')
# tensor([ 5364, 10985,   277,    32,  2943,  2485,   168,     0,  1741,  2549,
#            24], device='cuda:0')
# tensor([ 6390,   127,    67, 10640,    42,   902,    56,  1087,    78,   197,
#            56, 46878,    39,   998,   701,   620,    79,    32,  4462,    18,
#            24], device='cuda:0')
# tensor([ 397, 2630,   56, 1087,   79,   24], device='cuda:0')
# tensor([  56,  335, 8842, 4552, 4462,  426,  440,  335, 2591,   24],
#        device='cuda:0')
# tensor([   15,   274,  2551,    18,    32,   397,  1541, 41074,    24],
#        device='cuda:0')
# tensor([4850,   34,  934,   24], device='cuda:0')
# tensor([   79,    44,   902,    19, 46645,    79,   817,  3632,    32,  6155,
#            18,    32,   397,  7872,  4101,    24], device='cuda:0')
# tensor([   15,  2995, 44495,  1793,   377,    18,    24], device='cuda:0')
# tensor([  15, 4106,  902, 1506,   18,   24], device='cuda:0')
# tensor([ 5364, 11726,   238,     0, 23410,    32,   619,   996,   397,  4641,
#            32,   335, 34582, 46879,    24], device='cuda:0')
# tensor([   15,   902, 11282,    79,    56, 26916,    56,   711,  4116,    67,
#          2507,    56,  2096,    19,  3022,    44,  5010,   902,    32,  2578,
#            18,    32,   397, 13189, 18047,    24], device='cuda:0')
# tensor([   15,   604, 46875,   799,    18,    32, 44601, 36872, 46880,    24],
#        device='cuda:0')
# tensor([  15, 4887, 2421,  266,  902,  998,  701,   24], device='cuda:0')
# tensor([  185,   723,  2279,    78,    56, 11984,    26, 41538,    24],
#        device='cuda:0')
# tensor([  582,  6699,   155,   519,   397,  3780,   127,   163,  3197,   104,
#             0, 23326,    18,    24], device='cuda:0')
# tensor([   15,  5364,    34,  1888, 28588,    56,   711,  4090,    26,    70,
#          1153,    24], device='cuda:0')
# tensor([  15, 2929,    0,  296,   18,   32,  397, 1491,  193,   67, 6604,   24],
#        device='cuda:0')
# tensor([   15,   185,   723,   996,  2619, 46881,     7, 15574,  5695,  6260,
#            32,  4462,    18,   475], device='cuda:0')
# tensor([   15,   902,  3240,    95,    56,   998,  2551,    18,    32,  7467,
#         36872,    24], device='cuda:0')
# tensor([ 5034,     0,   105,    67,  5168,  3259,    32,   397, 22763,   335,
#         46882,  2044,    39, 23132,   817,   607,     0,  3423,    24],
#        device='cuda:0')
# tensor([ 5364,   586,   701,   577,    32,  1680,   374, 11102,    24],
#        device='cuda:0')
# tensor([  168,     0,   484,  7122,   397, 13481,  3257,   440,    56,   577,
#            26,    42,   335,  4160,    32,    39,   141,    67, 14596,    80,
#           274,   698, 36872,  8562,     0,  2732,  1361,   168,     0,  2946,
#             9,     0, 23858,    39,   535,  4332,  2485,     0, 28387,    42,
#         46883,    24], device='cuda:0')
# tensor([    0,  2947,    44,    32,     0, 46623,    44,   118, 36421,    39,
#         46884,    50,   335,  1104, 17493,  5011,    24], device='cuda:0')
# tensor([   15, 46881,  1969,  2930,    56,   698,  2551,   859,   277,    18,
#            32,   397, 46885, 28173,    24], device='cuda:0')
# tensor([ 619,   34,  397,  274, 3073,    0, 6260,  168,  725, 5477,  397,  406,
#         1888,   95,   48, 1512,   26,   78, 1518, 3000,   24], device='cuda:0')
# tensor([  859,    39,  3309,    19,    32,   122,    32,    44,   335,  8700,
#          7723,     9,  5137, 46886,  1687,    26,    11,  2008,    24],
#        device='cuda:0')
# tensor([   15, 46844, 46842,  1178,    95,  2528,   620, 46873,   197,  2990,
#           397,    44,   616,   475,    39,   399,  2375,   406,    95,   616,
#           701,    18,  1453,  1453], device='cuda:0')
# tensor([397, 469, 772,  24], device='cuda:0')
# tensor([   15,  1507,     0,  3919,   519,  2282, 29270,  3627,   552,    67,
#          3622,    42,    19,   197,    24], device='cuda:0')
# tensor([1781, 1480,    9,    7, 3884, 1212,   19,  127,   18, 1453, 1453],
#        device='cuda:0')
# tensor([ 4686,   377,    32,   397, 28278,    56,  1469,   168,     0, 13015,
#          8877,     9,    67,   789,    24], device='cuda:0')
# tensor([   26,  2586,    16,   179,   606,  1480,  1469,    56,     7, 11519,
#           771,  2199,  2199], device='cuda:0')
# tensor([  185,   104,     0,  1361, 28603,    34,    67,  2636,    24],
#        device='cuda:0')
# tensor([24293,   440,    32,  4462, 11083,  9724,    24], device='cuda:0')
# tensor([  124,  2756,  1032,    79,  1993,  2032,   475,    67,  4433,  1904,
#            32,  2629,    50,    67,  1054,    32, 18347,   374, 13015,    24],
#        device='cuda:0')
# tensor([  141,   571,   141, 36872,  1212,   549,     0,  5691,  1993,   254,
#             0,  2181,     9,     0, 46883,  9733,   627,    24],
#        device='cuda:0')
# tensor([  397, 46238,   440,    26,    67, 46887,    24], device='cuda:0')
# tensor([ 163, 2243,  141,  397, 1442,   32,   66,  335, 4054, 1212,  127,  277,
#           24], device='cuda:0')
# tensor([ 550,   80,   79, 1451, 1453, 1453], device='cuda:0')
# tensor([45306, 24470,    56,     0, 46882,   397,   655,   607,   168,    67,
#          3731, 46888,    32,   193,  8700, 15321,    24], device='cuda:0')
# tensor([  335,   484, 17428,     9,     0,  9733,   627,  2485,     0, 46889,
#         28387,   616,   701,  2661,    24], device='cuda:0')
# tensor([  996,    67,  4733,  3981,    32,     0,  4661, 46890,     9, 12711,
#            66,  1326,    56,   634,   335,  1831,    24], device='cuda:0')
# tensor([ 2099,    67,  3432,  4332,    42,     0,   627,    32,   397,    44,
#          3710,  2095,  4496,   266,     7, 12145, 28877, 27208,   682,  1304,
#            56,   335,   480,    24], device='cuda:0')
# tensor([  266,    79,    44,  2629,    50,    67,  3919,    32, 29889,  1532,
#          1950,    32, 36872, 44656,  3160,   656,   238,    67,  9085,    24],
#        device='cuda:0')
# tensor([ 397, 1442,  879,  550,  397,   44,  440,  612,   24], device='cuda:0')
# tensor([20232,    44,   456,   277, 32699,    26,     0, 46889,  1198,    44,
#         46891,     0, 46883,   627,    39,    32,  2400,  4927,   335,  3427,
#            32,    44,  2289,    56,  3879,   701,   607,   482,   397,  1212,
#           987,   238,     0,   814,    24], device='cuda:0')
# tensor([ 8124,   772,    42,  2400, 28468,   456,     0,   665,  1907,   776,
#          1060,    67,  7323,    26,   335, 23410, 18373,    32,  4462,  3823,
#           335, 23035,    39,  4148,    79, 11171,    24], device='cuda:0')
# tensor([  901,   397, 17888,   470,     0, 28513,   406,   670,   701,    56,
#          2541,  3981, 46892,    32,   397,    34,   335,  2820,    67,  8262,
#          1032,    24], device='cuda:0')
# tensor([  15,  859,   78, 1499, 3260, 3260], device='cuda:0')
# tensor([ 397, 6299, 2705, 2243,   18, 3260, 3260], device='cuda:0')
# tensor([   67,  1917,  6330,  5729,    56,   701,  2485,     0, 14974,    24],
#        device='cuda:0')
# tensor([   67, 23296,  5114,   374, 12924,    32,    39,    67, 12756, 39892,
#         31042,   254,     0, 14974,   607,   168,   179,  1953,    24],
#        device='cuda:0')
# tensor([    0, 13745, 34823,    34,   335,  2782, 10541,  4625,  1304,    24],
#        device='cuda:0')
# tensor([46642,    32,  4462,  2250,   620,  1817,    24], device='cuda:0')
# tensor([ 557,    0, 1165,   78, 9085,  813,  557,   67, 3747,   24],
#        device='cuda:0')
# tensor([  757,   335, 18749,    32,   397, 20998,    19,  1499,    32,   274,
#         46893, 14221,   397,    44,   110,  5668,     0,  2444,     9,     0,
#          4288,  1361,    24], device='cuda:0')
# tensor([10824,   440,   582,    32,    39, 24165,  2942,   859,     0, 14106,
#            32,   397,   144,   335,  7215,   817,     0, 28626,  3747,    24],
#        device='cuda:0')
# tensor([  397,    34,   274,  1621,    67,  2420,  4735,   482,    67,   789,
#          8819,   254, 10054,  1940,    24], device='cuda:0')
# tensor([  397,    34,    48, 13857,    32,    39,   335, 22410, 24736,   771,
#           404,   771,    24], device='cuda:0')
# tensor([   67,   771,    88,   124,   796,  4371,   482, 36872,  1216,   679,
#         22337,   168,   335, 10271,    24], device='cuda:0')
# tensor([   67, 12756,    34,  3992,  2319,     9,   335, 46894,  3981,    24],
#        device='cuda:0')
# tensor([   67,  3919, 43837,   335, 46895,    32,    39,   397,  1216,    67,
#           386, 18995,   104,   335, 12997,  5159,    24], device='cuda:0')
# tensor([ 1049, 21030,  1304,  9161,    24], device='cuda:0')
# tensor([   15, 42930, 21446,  3260,  3260], device='cuda:0')
# tensor([10351,   987,   456,     9,   964,    18,  3260,  3260],
#        device='cuda:0')
# tensor([  168,     0,   484,   771,  4462,    34, 28441,   335,  7215,    56,
#             0,   832,   557,     0,  1953,     9,     0, 14540,  3747,    24],
#        device='cuda:0')
# tensor([    0,   714,  1516,   482,   397,  3364,   161,  1198,   805, 13348,
#            24], device='cuda:0')
# tensor([9260,   67, 3259, 2044,   32,  397,  725,   19,  397,   44, 9116,   42,
#            0, 8262,   24], device='cuda:0')
# tensor([  397,  1024, 26572,   254,  1940,   701,    32,   185,   397,  1212,
#           473,   456,    16,  5919,    24], device='cuda:0')
# tensor([  397, 18180, 32884,    42,     0,   155, 39003,  4741,    26,     0,
#          3747,    32,    39,   552,    79,    24], device='cuda:0')
# tensor([31613, 28508,     0, 46882, 29893,   238,     7, 39680,  3747,    32,
#           397, 15980,  2942,   193, 33068,  1831,    24], device='cuda:0')
# tensor([ 2311,     0, 10464,  8794,  9068,    32, 12941,   701,   557,  2732,
#          1361,    24], device='cuda:0')
# tensor([ 619,  397,  487, 2507,   79,   24], device='cuda:0')
# tensor([  397, 26563,   456,     9,     0, 38293, 10464,    32,     0,  4917,
#          4379,  3976,  1940,   701,    32,    39,  7467,    67,  3259,   620,
#            24], device='cuda:0')
# tensor([ 2226,    26,   666,     0, 16086, 12236,   934,    56,   788,   456,
#             0,  3209,  4255,    24], device='cuda:0')
# tensor([   39, 46896, 26494,   721,   226,   484,  7479,   104,     0,  3683,
#          1825,    24], device='cuda:0')
# tensor([ 603, 4647,   19, 1212, 5214,   44, 1034,  238,    0, 2431,   24],
#        device='cuda:0')
# tensor([29382,    22,  1426,  7572,    39,   796,  2107,  2485,     0, 19888,
#            39,  1793,     0,  1856,  1069,     9, 46897,    56, 46898,    24],
#        device='cuda:0')
# tensor([5279,    0, 2422, 4524,   88, 5729,   44,  335, 3990,   24],
#        device='cuda:0')
# tensor([46899,   193,  1426,    44,    56,  7853,     0, 28485,  1068,  1764,
#            32,   193,   335,  2058,  3334,    56,   987,    20, 46900,   482,
#           199,   737,    56,     0,  7572,    24], device='cuda:0')
# tensor([46901,   772,    22,   124,  8872,    32,   193, 46902,   757,     0,
#          3919,    32,    56,  7853,    39,  3259,    42, 15839,     9, 12877,
#          2044, 46903,   104,     0,  1585,  1069,     9, 28485,    24],
#        device='cuda:0')
# tensor([  492,  4647,  3211,   124, 46904,  9096,  6460,    24],
#        device='cuda:0')
# tensor([   67,  8918, 26139,    22, 46901,    32, 46902,    32, 46905,    32,
#          5750, 18730,    32,    39,  8433,    39,     0,  1447,     0,   124,
#          3400,   254,     0, 31105,  1764,    56,     0,  8853,    24],
#        device='cuda:0')
# tensor([   79,    44,    67,  3521,   714,  3419,   190,     0,  4971,    39,
#         16585, 11858,    24], device='cuda:0')
# tensor([  16,  179,   34, 1480,   56, 1506,   24], device='cuda:0')
# tensor([    0,  8845, 30697,   817,   168,   102,    24], device='cuda:0')
# tensor([  277,    44,    67,  3112,    19,    78,  1237,   406,   127,  6268,
#           697,   191,     0,  1447,    39,    19,    78, 33179, 15219,  5168,
#          2139,     9,  3683,   406,   577,   104,  5387,    24],
#        device='cuda:0')
# tensor([    0,  2751,  4331,   102,   607,   168,     0,  1973, 46906,  6072,
#           190,     0, 13500,    24], device='cuda:0')
# tensor([46907, 26534, 46908, 44338,   254,   701,   193,    67, 17793,  7740,
#            39,   881,  3937,    56,     0,  4647,   193,    79,    24],
#        device='cuda:0')
# tensor([ 335,  480,   44, 5168,  141,    0, 8845, 3309,   79,  141,  397,  743,
#          104,    0, 4646,   39, 4938,   42,  335, 8840,   24], device='cuda:0')
# tensor([46901,  8794,   238,     0,  8795,  3112,   141,   901,   397,    34,
#          1888,    48,    26,   179,   482,    24], device='cuda:0')
# tensor([  185,   335,  3627,    39,  1653,     9, 46907,  4461,   825, 24464,
#            39,  4293,    26,     0, 46909,  1566,    24], device='cuda:0')
# tensor([   15,  4850,   737,  4116,   141, 19725,   141,   723,   641,    18,
#            32, 46907,     5,    32,   141,   397,  4331,     0, 46910,     9,
#             0, 46911, 23060,   859, 46908, 12114,    24], device='cuda:0')
# tensor([   15,   185,    78, 43297,  1877,    24], device='cuda:0')
# tensor([ 1507,    42, 46912,   274, 26860,    18,    24], device='cuda:0')
# tensor([  15, 2939,  473,  456,   24], device='cuda:0')
# tensor([ 3240,   902,  3234,    32,  1139,    18,    32, 46901,  1457,    32,
#         15120,   901,   397,   772,  2391,    79,    24], device='cuda:0')
# tensor([   15, 43604,    24], device='cuda:0')
# tensor([  698,   902,    18,    32, 46907,     5,   141,   397,  5881,   607,
#             0,  4646,    24], device='cuda:0')
# tensor([    0, 15756,    44,   335, 46913,    32,   335,  2732, 16536,    56,
#           793,  5011,    32,    39,   335, 14215,    19,  8840,    39,  4647,
#           406,  1969,  1087,    24], device='cuda:0')
# tensor([  168,     0, 46914,   519,    32, 46901,  2630,     0,  8837,    39,
#         46915,   456,    24], device='cuda:0')
# tensor([  254,     0,   519,     0, 46916,   476,  3257,  2215,     0,  4647,
#            44,   456,     9, 11922,    32,   397,  1442, 46907,   406,  2959,
#           335,   392,    56,     0,  8853,    24], device='cuda:0')
# tensor([  397, 17888,   536,     0, 20489,    34,  7012,    19,    79,    44,
#          2786,  5011,    42,    67,  8674,  1139,    56,  3443,   335,  4647,
#           145,   607,   104,    67,  3683,  1237,    24], device='cuda:0')
# tensor([  619,   714,   482,     0,   785,   519,    42,  1087,    32, 46907,
#           406,   127,  6655,    42,   603,  8843,    26,     0,  8845,    24],
#        device='cuda:0')
# tensor([46901, 46917,   817,     0,  3521,  3917,  3114,  8853,    32,    39,
#           179,    50,   179,     0,   866,   693,     9,   335,  4640,  5700,
#            26,  1940,   701,    24], device='cuda:0')
# tensor([    0,  5168,  4563,  6460, 14318,   224,   492,  4646,  2250,  1215,
#            39,  5417,    24], device='cuda:0')
# tensor([    0, 46155, 10096,  2250, 14461,  2511,    24], device='cuda:0')
# tensor([    0,  2124,   448,  2006,   701,  1838, 12759,  5488,    32,    39,
#             0,  2961, 11974,     9,     0,  8837,    19,    22,   701,   607,
#             0,  3521,  8853,  2681,   110,     9,     0, 16319,     9, 46907,
#            24], device='cuda:0')
# tensor([46908,  1237,    44,     0,   665,    56,  3416,    32,    39,   141,
#           397, 29808,     0,  7572,   607, 46918,   397,   725,     0, 16086,
#           476,  3082,   817,  2032,    24], device='cuda:0')
# tensor([   56,     0,  1165,    32,     0,  5168,  2971,  7050,     9, 28485,
#           476,  1186,    26,     0, 16086,   620,  3410,   440,   894, 24886,
#            24], device='cuda:0')
# tensor([13760,   701,     0,  8774,    44,    67,  5168,    39, 44938, 10786,
#            24], device='cuda:0')
# tensor([ 1188, 44936,   612,   335, 10877,   141,   397,   813,     0,  4640,
#            26,    39,   456,     9, 45544,    24], device='cuda:0')
# tensor([    0,  3917,  8853,   199,    34,   488,   607,   254,    44, 11619,
#          6553,   612,     0,  2971, 13500,  2044,    79,    24],
#        device='cuda:0')
# tensor([  397, 18174,     0, 13493, 33704, 17238,     9,  2786,  3409,    39,
#         10767,  3976,    32,    39,   397, 17888,    32,   901,     0, 14751,
#            80,   753,    32,   470,   397,    39,     0,   105,  8872,   406,
#           127,  1389,    56,    81,   894,  1499,   392,    26,    78, 10804,
#          2265,    24], device='cuda:0')
# tensor([  397, 36694,    26,     0,  7422,  8795,    24], device='cuda:0')
# tensor([    0, 26893,    44,  5235,  3309,   701,    24], device='cuda:0')
# tensor([  141,  2243,   141,   397,  1212,   698,   277,    44,    16,  4469,
#            56, 25185,   190,    79,    24], device='cuda:0')
# tensor([  199,   406,    95,    56,   577,  1165,   190,     0,  5679,  8231,
#          7001,    19,  6205, 28485,   254, 46919,    39,  2620,    19,    79,
#           751,  1304,    26,   482,   199,  1491,    24], device='cuda:0')
# tensor([46901,  1465,     0,  1479, 23602,   104,   335, 45586,    24],
#        device='cuda:0')
# tensor([   15, 46902,    32, 10351,  2791,    56,   577,   224,    78, 10775,
#            24], device='cuda:0')
# tensor([1707,   26, 1304,   39, 2939,  577,  440,    0, 7001,   18,   24],
#        device='cuda:0')
# tensor([   15,  5594,    32, 46896,    18,    32, 46902,  1350,   392,    32,
#            39,  3257,   335,   293,    26,    39,  8501,  3309, 46901,    24],
#        device='cuda:0')
# tensor([46901,    22,     0,  5571,  3770,  2044,   524, 46920,  1225, 12802,
#            19,   476,  3482,  1856,   859,     0,  1068,    24],
#        device='cuda:0')
# tensor([  397,  4331,   817,    56,   489,  2420,  2935,    32, 10824,    67,
#           833,  1856,     9,     0,    29,     9, 46918,    32,    39, 46921,
#           238,     0,  4253,    19,  5158,   612,     0, 19890,    24],
#        device='cuda:0')
# tensor([    0,  7001,    44,    66,    67,  1907,  2420,  4735,  3770,   193,
#           749,   620,  1576,   934,    42,    67,  7850,  4398, 46922,  4741,
#            24], device='cuda:0')
# tensor([   79,    44,    66,    67, 17034,  4640,    32,   185,   482,    79,
#            44,   190, 46901,  1216,   772,  3921,    67,  1363,     9, 46923,
#            24], device='cuda:0')
# tensor([    0, 14751,  4900,  5235,  3309,   102,   168,   620,  1426,  2420,
#          2935,    32,    39,   168,  2491,     0, 15052, 46924,   805,   620,
#            56,  1304,    26,    24], device='cuda:0')
# tensor([  901,     0,   105,  8818,   476, 21146,    32,   199,    80,   274,
#          2251,    79,    24], device='cuda:0')
# tensor([   0, 5571, 3584, 3649,   24], device='cuda:0')
# tensor([ 266,    0, 8774,   44, 7712, 2797,    9,  102,   32,    0, 4773,   44,
#          141, 2271,  141,  901,    0, 4693,   34, 2079,  456,   24],
#        device='cuda:0')
# tensor([ 397, 6072,    0, 4640,  456,   39,  813,  102, 2485,   67, 2425,    9,
#         2974,   39,  582,  817,    0, 1069,   24], device='cuda:0')
# tensor([1028,  199, 3823, 4269, 2095,  225,  199,  725,   16, 2949,    9, 2484,
#           24], device='cuda:0')
# tensor([ 2031, 46902,  4098,   397,    34,  4927,    67, 10880,    39,   796,
#           817,    56,    57,   648, 46901,  1621,   701,    24],
#        device='cuda:0')
# tensor([  15, 4119, 4472, 2563,   56,   79,   18, 3260, 3260], device='cuda:0')
# tensor([46902,     5,   859,     0,  1479,   141,   397,  1993,   392,   440,
#            26,  5571,    24], device='cuda:0')
# tensor([26877,  3644,    56,   127,  1393,    32,    39, 46901,    44,  1888,
#          1389,    56,   987,  3309,    67,  3442,  2935,    24],
#        device='cuda:0')
# tensor([   79,    44, 12299,    24], device='cuda:0')
# tensor([  335, 46925,   476,  2165,  1672,     9,     0, 13200,     9,  2422,
#         22891,   552,    50,   105,  8872,    24], device='cuda:0')
# tensor([  397,  4098,  2031,    19,   397,  3131,     0,  1936, 18364,  4114,
#             9, 46899,  4716,    67,  1164,    24], device='cuda:0')
# tensor([  185, 46908,  1764,  3584,   141, 19867,   141,    67,  4505,  7920,
#            24], device='cuda:0')
# tensor([ 1033,    32,   141,   519,  3997,    56,   407,   456,    32,   397,
#          3482,   238, 46903,    39, 46926,    67,  1081,     9,  3805,    19,
#         15501,    34,  4098,   203,  9120,  9381,  7308,    24],
#        device='cuda:0')
# tensor([    0,  3181, 16086,   552,  4001,  2078,    24], device='cuda:0')
# tensor([  277,    44,   274,   934,  1576,    56,   473,     0,  3064, 14985,
#          3946,   407,    24], device='cuda:0')
# tensor([    0, 18365,    44, 40170,    24], device='cuda:0')
# tensor([  179,     9, 46908,  6460, 12354,   440,    32,    39,   397,    44,
#          3400,   254,     0,  3990,   482,   397,  1212,   987,  8757,     9,
#            79,    24], device='cuda:0')
# tensor([   66,   179,     9,     0,  4640,  4861,    67,  1786,  4494,    39,
#             0,  6492, 29835,   440, 13500,    24], device='cuda:0')
# tensor([  193,   894,  1364,     9,  6460,  2705,    32,     0,  8151,  4461,
#         25039,    39,  5698,    24], device='cuda:0')
# tensor([46901,   796,   440, 11846,   612,     0, 14751,    39,   813,   102,
#           392,    56,   894,   306,    56,   377,    24], device='cuda:0')
# tensor([42983,    32,    79,    44,   996,  2732,    24], device='cuda:0')
# tensor([  697,    67,   373,   483,    67,  4436,  8875,    32, 46901,    22,
#          1672, 15224,    39, 15980,   392,   238,     0,  7001,    24],
#        device='cuda:0')
# tensor([  397,    44,   620,    56,   473,    67,  1111,  2323,   104,   335,
#          4640,   266, 46927,  4114,  4751,    26,   290,    15, 46928,  3260,
#          3260], device='cuda:0')
# tensor([  524, 46929,    24], device='cuda:0')
# tensor([3216, 5177, 2444,   18,   24], device='cuda:0')
# tensor([46908,  3551, 46391,   440,   254,   335, 10767,  3296,    24],
#        device='cuda:0')
# tensor([  397,   725,   102,    32, 29822,   612,     0, 10786,    32,   185,
#          9270,  4496,    24], device='cuda:0')
# tensor([ 199,  476, 3482, 4332,   42,  492,  105,  104,   67, 8298, 3432,   24],
#        device='cuda:0')
# tensor([5875,   88, 2422, 1453, 1453], device='cuda:0')
# tensor([   0, 3034,  604, 1013,   24], device='cuda:0')
# tensor([   39,    66,    67,  1907, 12179,    56,  2820,    79,    24],
#        device='cuda:0')
# tensor([   15, 39586,    18,  3260,  3260], device='cuda:0')
# tensor([46902,     5, 31637,    32,    39, 11836,    24], device='cuda:0')
# tensor([   39,   582,   397,  4098, 46902,   203,   127,  1113,    24],
#        device='cuda:0')
# tensor([  335,  1996, 46391,   190,     0,   340,  9742,   397,    34,   254,
#             0,  1259,     9, 11450, 11290,    24], device='cuda:0')
# tensor([  397,  9473,     0,  5960,   817,    56,   124,   290,  2728,    67,
#         22328,    88,    67,  3235,  3236,  3484,  2536, 11450,    24],
#        device='cuda:0')
# tensor([  901,    79,   476,     0,  2422,    32, 46930,   335,  2782,    44,
#          2613,    24], device='cuda:0')
# tensor([ 9381, 11450,   476,   412,   104, 46931,    32,  1476,   104,  1831,
#            39, 46932,    24], device='cuda:0')
# tensor([  335,   395,  1210,  8833,    32,   440,   612,     0, 26893,    32,
#          2006,   701,     0,  3036,    56, 11249,   335, 13012,    24],
#        device='cuda:0')
# tensor([ 185,   79,  153,  552,  701, 1902,   56,    0, 2422,   32,  901,   79,
#           44,    0, 2422,   32,   39,  397, 5842,   48, 4927, 1659,   24],
#        device='cuda:0')
# tensor([  185,     0,  9270, 11450,  5158,    16,   493,     9, 46933,   254,
#           894,  2558,  3432,    24], device='cuda:0')
# tensor([   26, 12179,    32, 46901,   552,   335,  3316,    24],
#        device='cuda:0')
# tensor([  397,  1465,     0,  1479, 23602,    24], device='cuda:0')
# tensor([   15, 46896,   428,    32,  4494,     0, 17280,    24],
#        device='cuda:0')
# tensor([ 4123,     9, 45586,    24], device='cuda:0')
# tensor([46902,    32,   902,   145,     0,   179,   104,     0,   832,    24],
#        device='cuda:0')
# tensor([2995,  145,    0, 3222,   24], device='cuda:0')
# tensor([46905,    32,     0,   179,   104,     0,  1113,    24],
#        device='cuda:0')
# tensor([  901,  6028, 46934,    24], device='cuda:0')
# tensor([10351,   473,  4105,   484,    18,    24], device='cuda:0')
# tensor([46901,    34,     0, 10353,  2942,    39,     0, 45586,   440,   482,
#           397,  1024,     0,   124,    15,  8777,    18,    24],
#        device='cuda:0')
# tensor([    0,  8151,    32,  4269,   193,   588,     9,     0,  1111,  7233,
#           456,    32, 11279,  8849,    24], device='cuda:0')
# tensor([46908, 46935, 25327,    44,   859,  4060,   266,   397, 21261,   607,
#           749,  3309,     0,  6284,    24], device='cuda:0')
# tensor([    0, 21256, 11450,  3644,    56,  2079,   104,    24],
#        device='cuda:0')
# tensor([ 199, 3721,   56,  127,    0, 2422,   24], device='cuda:0')
# tensor([46901, 12106,     0,  2431,  1335,    34,  3644,    56, 16825,  8151,
#            24], device='cuda:0')
# tensor([ 277,   44,   32,    9, 3432,   32,   16, 1499,   42,    0,  105, 8151,
#           56,  987,   50,  102,   24], device='cuda:0')
# tensor([  79,   44,   67, 6368,   24], device='cuda:0')
# tensor([ 185,  199, 1212, 4741,   39, 3150,   56,    0, 1585,   24],
#        device='cuda:0')
# tensor([46901,  1465,     0,  1479, 23602,  2032,    24], device='cuda:0')
# tensor([   15, 46902,    32,   753,  1455,  3919,  1854,   392,    24],
#        device='cuda:0')
# tensor([ 901,   20,    9, 2563, 2452,   32,  199,  641, 3086,  440,    0, 9931,
#           24], device='cuda:0')
# tensor([  879, 10351,   473,  4105,  6028, 46934,    18,    24],
#        device='cuda:0')
# tensor([ 1532,   141,   397,     5,    79,    32, 46901,  1442,   199,    34,
#           236,     0,  2422,    24], device='cuda:0')
# tensor([    0, 14648,   476, 16270,    39,     0,  1738, 28041,   476,  2136,
#           440,    32,  8501, 14957, 46936,    26,     0, 10786, 16656,    24],
#        device='cuda:0')
# tensor([46901, 43480,   335,  2591,  2485,     0, 19281,    19,  2575,   104,
#             0, 12711,    39,   789,  7464,    39,   789, 11922,    24],
#        device='cuda:0')
# tensor([    0,  8571,   193,     0,  7480,    26,     0,  3461,  5158,   440,
#         10037,   104,     0, 38005,  6588,    26,  3978,     9,   701,    24],
#        device='cuda:0')
# tensor([  335,  3627, 26508,    24], device='cuda:0')
# tensor([   15,  5159,  1455, 12711,    32, 46928,    18,    24],
#        device='cuda:0')
# tensor([   15,  6028, 46934,    24], device='cuda:0')
# tensor([ 6028, 46934,    18,    32,  1993,    67, 24923,  4114,    24],
#        device='cuda:0')
# tensor([   15, 46901,    56, 46896,   428,    24], device='cuda:0')
# tensor([179, 306,  66,  24], device='cuda:0')
# tensor([  16, 9100,   24], device='cuda:0')
# tensor([ 2928, 14788,  1455, 28050,    26,    78, 23858,    24],
#        device='cuda:0')
# tensor([4806,    7,  746,   18,   24], device='cuda:0')
# tensor([ 397, 4461,    0, 8872,  859,  612,  179, 3973,   24], device='cuda:0')
# tensor([   79,  2006,   102,   191,    67,  2507,    56,   473,    67, 13277,
#          9496,  4741,  1225,    39,    67, 46937,    19,   406,   274,   145,
#           102,   238,     0, 26893,    88,   454,    67, 46938,  3734,    24],
#        device='cuda:0')
# tensor([  901,     0,  4741,    44,   782, 11846,    32,    67, 11775,  7462,
#           406,  2997,   102,   456,    24], device='cuda:0')
# tensor([   67, 14463,     9,     7,  8833,    42,    67, 11775,  7462,    32,
#           185,    79,  1212,   127,   639,    24], device='cuda:0')
# tensor([46901,  4478,   335, 45586,    56,     0,   225,  3973,    39, 46165,
#           440,     0, 23006,    32,    39,     0,  8837, 11279,   141,   901,
#            79,    34,    48,  4104,    24], device='cuda:0')
# tensor([    0,  2212, 17727,  2422,  3644,   104,   141,   901,    16,   179,
#          2375,   476,  2044,    24], device='cuda:0')
# tensor([   15,   199, 19105,   187,  2563,    18,    32, 46901, 29867,    56,
#           772,   859,     0,  8837, 10352,    24], device='cuda:0')
# tensor([   15,   199, 19105,   187,  2563,    18,    24], device='cuda:0')
# tensor([  397,  4494,     0,  1479, 23602,    24], device='cuda:0')
# tensor([   15,   879,    32, 46928,    32,   879,    24], device='cuda:0')
# tensor([10351,   145,  5933,   377,    18,    24], device='cuda:0')
# tensor([  397, 22763,   392,   104,     0, 10353,    39,  1216,   335, 40108,
#         32039,    24], device='cuda:0')
# tensor([  456,     9,     0,  2924,     9,   335,  2462,    32,   397,  7533,
#           335, 46939,  2449,   456,    67,   755,    39, 17235,   440,   193,
#           701,    24], device='cuda:0')
# tensor([3649,   32,  397, 4098,   24], device='cuda:0')
# tensor([  193,     0,  2324,  2264,     9, 46940,    32,     0,  3427,   254,
#          5668,    32,     0,  1953,    32,    39,  2797,    32,   277,   406,
#           127,    66,    67,  8262,   266,  4645,  1212,   127,   639,    24],
#        device='cuda:0')
# tensor([  749,   697,  5667,   168,    67, 36542,   648,  2270,    67, 46941,
#           254,    67,  5191,   709,    24], device='cuda:0')
# tensor([  397, 46238,   335,  4741,    24], device='cuda:0')
# tensor([ 335, 4799,  440,   24], device='cuda:0')
# tensor([  79,   44, 1742,   56,  127, 5017,   24], device='cuda:0')
# tensor([ 1426, 11450,    26,    78,  2511,  6368,    24], device='cuda:0')
# tensor([ 4117,    32, 14509,  4208,    32,   473,  1018,  8818,   793,    32,
#           397, 14226,    24], device='cuda:0')
# tensor([  397,    22,    67,  4684,   104,     0,  2422,    32,  2674,    67,
#          2053,     9,   489,     9,     0, 38154,    26,   335, 24203, 11922,
#            39,   582,   276,  1049,    24], device='cuda:0')
# tensor([    0,  2422,    80,   274, 46281,    24], device='cuda:0')
# tensor([  79,   80,  274, 4852,   59,   19,  199, 5842,   48, 4927,   24],
#        device='cuda:0')
# tensor([ 4942, 13581,    24], device='cuda:0')
# tensor([ 879, 3260, 3260], device='cuda:0')
# tensor([46908, 14499,  6516,   104,     0, 10353, 23326,    24],
#        device='cuda:0')
# tensor([    0,  4647, 46917,    39,  3354,    24], device='cuda:0')
# tensor([ 1425,   993,  1794, 34338,   894,  1499,   238,     0, 10786,    39,
#         19329,    24], device='cuda:0')
# tensor([ 141,  901, 8399,   50,   67, 4687,    0, 2422, 4524,  238,  102,   24],
#        device='cuda:0')
# tensor([46901, 46238,   335,  4741,  2215,     0,  4647, 43239,    24],
#        device='cuda:0')
# tensor([5011,   44,  193,  701,   24], device='cuda:0')
# tensor([ 335, 8209,  426,   42,   67, 3919,  104,    0, 8837, 2415,    9,    0,
#         4647,   24], device='cuda:0')
# tensor([    0, 46942,  7563,  4524,   607,    26,  9931,    24],
#        device='cuda:0')
# tensor([   67,  1215,  9728,     9,  8837, 46943, 19329,    24],
#        device='cuda:0')
# tensor([   79,    44,   191, 46901,    34,   519,    56,   698,    24],
#        device='cuda:0')
# tensor([  335, 40508,    42,     0,   771,    34,  2501,   701,   571,     0,
#         26893,    32,   881, 10269,    39,  5258,   440,   238,     0, 16086,
#            24], device='cuda:0')
# tensor([ 335, 1831,   44, 3082, 2988,   24], device='cuda:0')
# tensor([  901,   397,  7704,   456,   879,    32,   397,   406,  4033,   335,
#         15163,   104,     0,  2095,    24], device='cuda:0')
# tensor([46939,    32,  1707,  1970,    32,   397, 14226,    24],
#        device='cuda:0')
# tensor([  397,  1465, 10353,    39, 46944,    39,  4357,     0, 26893,   104,
#           335,   392,    24], device='cuda:0')
# tensor([  397, 11705,     0, 11248,     9, 46945,    24], device='cuda:0')
# tensor([ 397,   34,   16, 1162,   33,   44,  440,   39,   33,   44,  817,   24],
#        device='cuda:0')
# tensor([ 397,  426,    0, 8740,  536,  199,   34,   48,   24], device='cuda:0')
# tensor([15017,  4447,   456,   859,   701,    39,   397,  1216,     0, 45672,
#           958,   335,  4417,    39,     0, 10353,  5285,    24],
#        device='cuda:0')
# tensor([  335,  2431,  1831,  4331,  2215,   397,  4098,   397,   406, 29888,
#           456,    24], device='cuda:0')
# tensor([  859,     0, 28401,     9, 46946,    32, 43319,     9,  7299,    39,
#         33721,     9, 37748,   277,    44,    67,  9841, 15817,     9, 30629,
#            39, 10129, 46947,    24], device='cuda:0')
# tensor([11692,  2431,  2134,  7290,   190,     0,  2732,    88, 46948,  1953,
#          9948,  6298,     9, 22281,  6687, 37481,    32,    39,  8758,    67,
#          8842, 23494,     9, 15179, 34047,   254,     0,   392,  3550,    24],
#        device='cuda:0')
# tensor([   15, 32483,    18,    32,  1018,  3115,  5284,  5012,   193,   679,
#           163,  3106,    32,   163,  1172,    26,   335, 11320,   723,  2031,
#           374,  2026,     0, 17085,    32, 46949,   191,  1018, 20602,  1887,
#             9, 11467,    56,  1790, 10539,    24], device='cuda:0')
# tensor([  209,   476,   985,    56,     7,  8185,    32, 11217,  1113,    32,
#         46950,    56,    67,  2956,    24], device='cuda:0')
# tensor([ 1382,    56,   200,    19,    78,    44,     0,    99,     9,    67,
#           570,  4449,  1951,   723, 32353,    67,   597, 24252,    39,  3231,
#           550,     0,    99,     9,    67,  8501,  7286,  1951,   406,   127,
#            42,     0,   604, 10465,   290, 32483,    32,   263,  9735,    24],
#        device='cuda:0')
# tensor([   15, 46951,    24], device='cuda:0')
# tensor([23087,    18,    32,   723,     5,    32, 27550,  1018, 12926, 27270,
#           104,  1018, 17409,    39, 43556,   179,     9,    67, 46952,  7225,
#             9, 11145,   193,  1018, 25394,  8090,    24], device='cuda:0')
# tensor([  723,  5321,   193, 30618,    39, 31424,    56,     0, 12593,  5627,
#          1029, 15210,   190,  1738,  8871,    39,     0, 38265,     9,     0,
#           392, 12248,  6588,    24], device='cuda:0')
# tensor([ 582,  723,  725,    0, 9766,  535, 8501, 4741, 2199, 2199],
#        device='cuda:0')
# tensor([46953, 18624, 14648,  3072,     0, 17314, 46954,     9,  5614,    24],
#        device='cuda:0')
# tensor([23831, 33978,   682,    24], device='cuda:0')
# tensor([46955,    39, 46956, 12345, 11894, 11964,   557,     0,  6566, 10980,
#            39,   682,  1018, 46957,    39, 20961, 26574,    24],
#        device='cuda:0')
# tensor([ 5284,    67, 17606,  8205, 14106, 46958,    32,    39,    32, 46959,
#         11836,    32,   723,   725, 41006,    26, 10877,  3966,   290,   993,
#         19758,    32, 34412,  7166,     9, 10987, 12109,    39,   475,  6669,
#            32, 14164,  3223,     9,  2620,    32, 20558,    32,  5653,   475,
#             0, 31840,   480,     9,   604, 46960,    24], device='cuda:0')
# tensor([   15, 46961,    18,    32,   397, 27247,    32,   335,  1466, 11860,
#         15298, 46962,  1653,     9,     0, 17118, 10987,    24],
#        device='cuda:0')
# tensor([  859,     0, 46963,  2377,     9,    67,  6436,  3550, 13513,  1265,
#           193, 12747, 46964,  6553, 46965,    44,   749, 26386,    32,   571,
#            32,    88, 46966,   571,    19,  5738,   536,   475,  7585,   475,
#           374, 46967,    32,   588,  8849, 46968, 12109,   487,   996,   127,
#         34412,   392,    26, 11692,    32, 14255, 11692,   531, 21119, 36646,
# ...
#            24], device='cuda:0')
# tensor([  582,   266,  2452, 47620,    44,   104,     0,    99,     9,     0,
#          1951,     9,  7792,    32,  4125,    32,    26,     0,  3222,     9,
#             0,  1951,    32,  2006,     7,  3645,  1030,  2541,    39,     0,
#          1741,   712, 14238, 47649,    32,  1587,   817,  1030,    32,  4116,
#          7178,  3976,   859,  4116,   535,    24], device='cuda:0')
# tensor([  648,  3022,    44,  9754,    56,   987,  4116,  6798,   817,    39,
#           987,   104,  4116,  2935,  2032,    32,  4125,  3937,   859,    32,
#           663,  4116,   335,  2591,    39,     5,    32,    15, 44587,    32,
#          1015, 12973,    32,  2452, 47620,    24], device='cuda:0')
# tensor([ 723,  751, 1451,   56, 2541,  163, 1030,   18,   24], device='cuda:0')
# tensor([   15,  4806,   191,  1113,    18,    32,  3022,     5,    32, 29900,
#          4116,   535,   392,    56,   987,     0, 12109,   456,     9,  4116,
#          3551,    24], device='cuda:0')
# tensor([   15,    79,    44,  1018, 14486,    18,    24], device='cuda:0')
# tensor([  193,   179,  2591,  3022,   426,  4116,  6798,   817,   648,  3022,
#            22, 34016,  1706,  2591,   193,     0,   105,    24],
#        device='cuda:0')
# tensor([  266,  4116,  2591, 12485,   335,    32,   225,   796,   190,  4125,
#            39,   397,  1216, 13531,    32,   185,   397,  8863,  9057,    56,
#           987,  4116,   104,  4116,  2935,    24], device='cuda:0')
# tensor([ 397, 4098, 3022, 2006,  701,   19, 3259,  193,    0, 7585,  679,   26,
#           79,  141,  397,  586, 4116, 2591,  577,   24], device='cuda:0')
# tensor([   15,  5954,   902,    18,    32,  3022,     5,    32, 24456, 10158,
#           607,    24], device='cuda:0')
# tensor([   15,   218,   902,  3622,   193,  2563,  2032,    32,  2452, 47620,
#            18,  1453,  1453], device='cuda:0')
# tensor([ 179,    9,    0,  833, 7792,    5,   24], device='cuda:0')
# tensor([  15,   16,  374, 1464,   24], device='cuda:0')
# tensor([6699,  213,  105,  633,   18,   24], device='cuda:0')
# tensor([   15, 14255,    32, 28065,    18,    32,     0,  6260,     5,    24],
#        device='cuda:0')
# tensor([  15,  723, 3240, 1009, 2995, 3622,   20,  374, 2566,   18,   24],
#        device='cuda:0')
# tensor([   15,  2551,  2566,    18,    32,  1447,     5,    32,    39,   784,
#             0,  4145,  4751,   440,    32,     0,   957,  1742,   607,    26,
#         21257,    32,    26,  9198,  2190,    39,  1645,    24],
#        device='cuda:0')
# tensor([ 4125,  5105,   607,  1645,   456,     0,   597,    26,     0, 47446,
#         14358,  4693,    32,   682,   421, 47650, 47651,    32, 47652,   627,
#            32,   557,     0,  1774,   536,     0,   105,  4851,   476,  4830,
#          4474,    32,  7890,     9,   550,   397,   406,   217,    26,   746,
#            56,   473,  2452, 47620,    95,   701,  1707,    26,   404,   718,
#           475,   880,    78,    44,     0,   633,   397,    34,  1143,   266,
#           397,  4098,   397,   725,     0,  3259,    26,  4116,  3551,    24],
#        device='cuda:0')
# tensor([  266,   397,  1993,   392,    56,     0, 19920,    32,   335,  1996,
#            44,   552,   440,    24], device='cuda:0')
# tensor([  397,  9729,   406,   274,   304,   335, 15681,  1381,   266,     0,
#           712,   426,   335,  6047,    24], device='cuda:0')
# tensor([   19,   126,   217,    79,    32,   397,  4098,    32,   880,  2452,
#         47620,    34,     5,  3022,    44,  1742,    56,   127, 20146,   620,
#           718,   304,    24], device='cuda:0')
# tensor([  397,    34,  2710,  5027, 47653,    88, 47654, 47655,   168, 12245,
#            88, 10273,     0, 12109,     9,     0,  6260,  1587,    26,  3978,
#             9,   701,    32,   185,   397,  1178,   145,    67,  2507,   104,
#          2728,     9,    96, 15021,   290,     0,   712,   930,   406,   473,
#           701,  2028, 47656,    26,    67,  2924,  1089,     9,  1707,    26,
#           404,   718,    24], device='cuda:0')
# tensor([    0,    66, 17557,   879,    56,     0,   313, 26509,  1143,   104,
#            44,    19, 12245,  2375,   203,  2830,    56,   217,   335,   304,
#            32,   782,    32,    39,     0,   712,   406,    95,    19,  1277,
#          1707,  4337,  1793,   193,  4125,    24], device='cuda:0')
# tensor([   15,   185,  4850,   737,    56,   145,    67,  2507,   104,    79,
#            18,    32,   397,   616,   772, 13631,    24], device='cuda:0')
# tensor([   56,   335,  4552,   335,   313,   653, 15887,    24],
#        device='cuda:0')
# tensor([   15,   191,  1113,    32,   901,   902,  1744,   217,  1455, 15681,
#           779,   718,  1259,   902,   641,   217,    79,   404,   718,   136,
#           456,    18,    32,  2452, 47620,     5,  1978,    32,   274, 18620,
#            24], device='cuda:0')
# tensor([   15,   902,   218,  1707,   964, 13021,  2756,   404,     0,  1447,
#           577,   377,    78,   541,    39,   304,  1455,  1381,    18,    24],
#        device='cuda:0')
# tensor([   39,   163,   266,     0,  1447, 47657,   456,    19,   541,  4125,
#          3584, 47658,    26,   335,  3550,   571,    67, 12248,    32,  2943,
#           456,    26,   550,   397,  1959,    44,    67, 32416,    43,    32,
#           648,     0,   105,  4899, 26537,    39, 29867,    26,   168,   701,
#            39,   552,  1029,   141,   199, 32559,    32,  1742,   377,    24],
#        device='cuda:0')
# tensor([  397, 12365,   725,   102,    24], device='cuda:0')
# tensor([  335,  1947,    44, 21184,   697,    67,  1813,  6490,    39,   397,
#            44,  3040,    56,  2619,    32,   335,  1996, 15237,    56, 27176,
#           168,   701,   697,    67, 11079,    88, 18976,   175,    32,    15,
#          1781,   218,   723,   217,    79,  1453,  1453], device='cuda:0')
# tensor([  104,     0,  9261,     9,     0, 23587, 18662,     9,  1466, 45229,
#           743,    67,  1741,  4750,     9,  5302,  6695,    39, 14202,    24],
#        device='cuda:0')
# tensor([ 3022, 47659,   833, 47660, 26942,  1350, 47661, 16512,    39,  1152,
#          4116,  2971,    32,  1936, 47662,  3551,  1979,   104,    67, 24843,
#          8467,   399,    44, 45255, 12434,   193,    67, 24268,  4734,  6690,
#         25647,  2044,   335, 14536,  5836,    24], device='cuda:0')
# tensor([    0,  2354,   193,     0,  6690,    34,    67,  1110,  8748,    39,
#         15818,     9,  2783,    33,  7676,    56,     0,  4750,    24],
#        device='cuda:0')
# tensor([16610,    39, 12029,    32,   397,    34, 47663, 10434,    32,    39,
#           335,  4269,  1395,   616,     9,     0,  2023, 21844,   399,    34,
#            48, 17724,   193,     0, 13094,  2693,     9,   335,  1367,    24],
#        device='cuda:0')
# tensor([    0, 43282,  1466,  6260,  2575,    56,    67, 10490,    32, 47664,
#           373,  9331,   168,  4116,  1953,    39, 30733,   290,    15,  3259,
#           168,  1455,  3443,    32,  6973, 47665,    24], device='cuda:0')
# tensor([   79,   136,   881,   519,    42,    39, 47666,    56,   584,    18,
#            24], device='cuda:0')
# tensor([ 6973, 10238, 47665,    44,   179,     9,   263, 47132,   588,  2331,
#            39, 14444, 13094,  3834,    24], device='cuda:0')
# tensor([  397, 43294,    39,  2006,     0,  1334,    42,     0,  5552,    56,
#          3306,    24], device='cuda:0')
# tensor([    0, 18733,  3937, 30708,    56,     0,  3461,     9, 11634,  3447,
#            39, 10996,  2044,    67, 43001,  2354,   199,  1350,  5435, 47667,
#            24], device='cuda:0')
# tensor([ 5435, 13100, 28360,   124, 47289,  8873, 15014,   612,     0, 47668,
#            33,  1326,   141,   335,  6395,    24], device='cuda:0')
# tensor([  397,  5158,   335, 22128,  3014,     9, 11860,    39, 26541, 47669,
#            32,   335, 15683,  8524,  5749, 45309,   141,   397, 26508,    39,
#         43196,    26, 17451,    24], device='cuda:0')
# tensor([    0, 18721, 22042,     0, 47668,   193, 10412,  5743,   141,     0,
#          6196,  3997,     0, 47666,    32,    67, 18454, 47670,    33,    34,
#           714,    48,    67,  6349,     9, 31737, 17055,    39,   894, 14216,
#            26,     0,  5006, 13094, 15325,    24], device='cuda:0')
# tensor([    0,  5552,    44,     9, 47671,  2789,    24], device='cuda:0')
# tensor([    0,  1466,  6260,   193,     0, 13143,  2971,  3551, 44991,     0,
#         10993,  2382,    56,  4116,    50,    67,  6348,   373,     9,   620,
#          1268,    32,   399,    34, 23572, 22259,    39, 47672, 44535,    24],
#        device='cuda:0')
# tensor([  397,    44,  6044,    26,   335,    43,    39,    32,  3642,    67,
#         13094,    32,  9374,    44, 13092,   404,    67,  4401,    39, 32215,
#             0, 19386,     9,   335,  3834,    24], device='cuda:0')
# tensor([  397, 13135,  6792,     0,   428, 23456,     9,  4116,   627,    32,
#            42,     0,  6260,    44,  9781, 47673, 47674,    32,   336,     9,
#             0,  5555, 27636,    32,  1294,  1076, 47674,    32,   399, 14254,
#           179,     9,     0, 30881, 12265,    39,   588,  5307,   496,    24],
#        device='cuda:0')
# tensor([47673,    44,    67, 47675,    26,  1265,  4067,    24],
#        device='cuda:0')
# tensor([ 3022,    44,    67,   418, 47676,    39,   179,     9,     0,  3691,
#           588, 17324,  6925,    24], device='cuda:0')
# tensor([ 1028,   263,  3385,    44,   274,    56,  1998,     9,    79,    42,
#            67, 10821,    32,  3022,   153,    44,    67, 47677,    32,    67,
#         47678,    39, 38802,  5273,   475,     0, 47679,     9,   213,     9,
#             0,  5910, 14653,   612, 14126,   724, 16007,   104,  1476,  9992,
#            24], device='cuda:0')
# tensor([ 9781, 47674, 31786,   193,  4116,  8013,  8745,   557,     0, 27126,
#          2354,   399,    44, 47680,    39, 22258,   193,     0,  4734,  6690,
#           996, 23516,   859,   335, 12370, 12114,    24], device='cuda:0')
# tensor([    0,  4748,    32,  6348,  2549,    44,  1350, 26947, 43300,    50,
#             0,   105, 18733,    24], device='cuda:0')
# tensor([  397,    44, 11991,   193,  3836, 25440,    39,    67,  7551, 47681,
#            42,  2693,     9,    20,   417,    24], device='cuda:0')
# tensor([  185, 26947,    34,    34,   833,  2875,   193,  7792,   104,   335,
#          1278, 27960,    26, 47682,  1586,   447,    24], device='cuda:0')
# tensor([13939,    32,  1579,    32,   397,  1905,  6918, 27092,    39,   805,
#          9928, 17546,     9,     0, 34738, 15144,   266,   199,   647,    56,
#           473, 47683,   193,   701,    26,     0,  2732,  9213,    32,    26,
#         23830,    39,    26, 47684,    24], device='cuda:0')
# tensor([   78,  1741, 13094,    44,  5791,  1498, 12531,   266, 47673, 47674,
#          8834,    19,  3022,   471,   701,    56,  3747,   571,    24],
#        device='cuda:0')
# tensor([    0,  4750, 33523,     0,  2354,   193,     0, 47685,    67, 19724,
#         28142,   203,  6895,   557,    67,  6035, 47686,    33,   136,   274,
#           619,    26,   335,  7836,    24], device='cuda:0')
# tensor([  15,  550,  136, 1455, 2448,   32, 3970, 1453, 1453], device='cuda:0')
# tensor([2079,   67,  755, 1950,   24], device='cuda:0')
# tensor([  723,  3780, 11856,    32,   902,  2421,    18,    24],
#        device='cuda:0')
# tensor([  397, 47687,   168,  9781, 47674,    39, 31195,     0,  1100, 15179,
#            33, 47688,   254,  4116,    24], device='cuda:0')
# tensor([  582,   397, 14361, 33507,    24], device='cuda:0')
# tensor([   15,  1018,  2448,   136, 26947, 43300,    32, 46325,    24],
#        device='cuda:0')
# tensor([  723,  9364,    56,  1309,  3684, 47689,    18,    24],
#        device='cuda:0')
# tensor([ 3022,     5,   193, 11172,  3112,   290,    15,  2079,   571,    32,
#           586,  2551,   210,  1455,  1946,    24], device='cuda:0')
# tensor([  902,  3259,  1498,   412,    39, 19090,    56,  2551,    32, 26947,
#            18,    24], device='cuda:0')
# tensor([  349, 47674, 44273, 47690,     0, 13094,   557,  4116,  4104, 35111,
#            24], device='cuda:0')
# tensor([22911,  4116, 34747,    32,  3022,  8794,    26,    32,  1888, 40004,
#          4116,  5285,   104,   335,  5159,    24], device='cuda:0')
# tensor([    0,  4750,   805, 10660, 30784,     9,     0,  6690,    33, 47691,
#           104,     0,  1824,    26,    67, 38746,    24], device='cuda:0')
# tensor([ 2031,  2009,     0, 47692, 16645,    32,  3022,  3823,     0, 21175,
#            39, 11983,    56,   711,     0,  1420,  2354,     0,  1146,     9,
#          9854, 22725,  3192,  9053,    42,  1336, 47693,    24],
#        device='cuda:0')
# tensor([ 4040,   168,   665,    32,    39,   404,    67,  1907, 27996, 47694,
#           104,  4116,  1687,    33, 10539, 47673,    19, 26947,    44, 10164,
#             9,  1249,   263,  6230,    32,  3022,   609,     0, 12248,    39,
#          1350,    56,  4116, 47695,  3115,    24], device='cuda:0')
# tensor([   78,    44,     0,  1191,   373,   193,     0, 47696,  2431,    39,
#             0, 47672,    32, 19730, 44535,    24], device='cuda:0')
# tensor([   15, 47697,  3260,  3260], device='cuda:0')
# tensor([  723,  2279,   902,    56,    81, 19946, 47689,   168,  2031,    39,
#           711,   701,    78,   197,    42,     0,  1245,  2848,    24],
#        device='cuda:0')
# tensor([ 4849,  3776,    26,  5614,    26,    78, 47698, 15254,    24],
#        device='cuda:0')
# tensor([  901,     0,   604, 10163, 19178,   620,     0,   802,    32,   998,
#           701,   723,  2952,   746,  1018,  5953,   274,    56,  8145,   701,
#           141,    67,  1677,    20,  7286,    24], device='cuda:0')
# tensor([47689,   186, 44376,    39,  3169,   104, 47699, 20025,    39, 47700,
#            24], device='cuda:0')
# tensor([ 6942,    32,   397, 11350,  1682, 18733,    24], device='cuda:0')
# tensor([ 179,  206, 6000, 1531,   56,  701,   18,   24], device='cuda:0')
# tensor([47697, 47701,    32,     0, 18095, 44196,   399,    34,    48,   430,
#            26,  7300,   525,   482,   254,   335,  3384, 36008, 47702,    32,
#         14361, 19495,    39, 12485,   335, 47703, 28672,  9700,    24],
#        device='cuda:0')
# tensor([  335, 14119,  3551, 45507,     0,  4750,    32,    39,    67, 26625,
#          4527,   203,  2355,    19,   277,    44,   374,    56,   894,  7684,
#           375,    19,     9, 13094,    56,  3233,    24], device='cuda:0')
# tensor([  15, 1049, 2354,   32, 9781,   18, 1453, 1453], device='cuda:0')
# tensor([    0, 47704,     5, 13408,    24], device='cuda:0')
# tensor([   15,    78,   179,   136,    67, 20014,  9878,    32, 43022,  1453,
#          1453], device='cuda:0')
# tensor([   70, 11143,  6695,    32,    70,  1096, 20868,    24],
#        device='cuda:0')
# tensor([   79,   218,  5186,    39, 41606,  5698,    42,  9781,    18,    24],
#        device='cuda:0')
# tensor([   15,   127,   758,    32, 47701,  3260,  3260], device='cuda:0')
# tensor([ 902,   86, 8752, 1455,   23,   18,   24], device='cuda:0')
# tensor([    0, 10012, 47704,  5105,   607, 10857,    26,  3368,     9,  3684,
#         47689,    24], device='cuda:0')
# tensor([47673, 47674,    22,     0, 23601,    26,  4116, 47705,  3627,    39,
#          4515, 26947, 43300,   475, 47706,    26,     0,   392,  3550,     9,
#             0, 35111,   475,    56,  4116, 10968,   168,  1546, 47707,  3423,
#            24], device='cuda:0')
# tensor([ 1294,  1076, 47674,   743,   104,     0, 46241,   168,     0,   535,
#             9,     0,  3964,    39,  7533,   335, 35111,   141,    79, 10967,
#             0, 19742, 10968,    24], device='cuda:0')
# tensor([26947,    32, 18991, 27568,   335, 13751,    32, 26770,   456,   168,
#             0,   296,   254,     0, 12248,     9,     0,  2410,    24],
#        device='cuda:0')
# tensor([  397,   725,    67, 47708,   373,   193,    67, 44901, 22313, 20540,
#            39,     7,  8216,  1215,   535,    24], device='cuda:0')
# tensor([ 1294, 47674,  6792,    67, 23596, 36137,  6836,    32,    39,   335,
#         47709,  3551,   476, 47710,    39, 23598,  1940, 19690, 23931, 18644,
#            24], device='cuda:0')
# Epoch : 20 -- Training loss : 0.02261645097724782,	 Validation loss : 0.01063150738782539,	 Time : 3.0m 32.25500202178955s

# %% [markdown]
# # Loading trained model

# %%
model = POStagger(len(word2id), len(tag2id), EMBEDDING_DIM, HIDDEN_STATE_DIM).to(device)
model.load_state_dict(torch.load("/content/drive/MyDrive/IITB/Sem6/CS772/A2/model20_encoder"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Testing

# %%
testing_loss = 0.0
precision = {}
recall = {}
f1 = {}
f0_5 = {}
f2 = {}

pred_tag = np.zeros((len(tag2id),len(tag2id)), np.int32)

model.eval()
for (xs, ys) in zip(test_x, test_y):
  with torch.no_grad():
    model.hidden_state = model.hidden_state_initialize()

    probs = model(xs)

    loss = criterion(probs, ys)
    testing_loss += loss.item()

    # j = 0
    # for p in probs:
    #   pred = 0
    #   for i in range(1,len(tag2id)):
    #     if(p[i] > p[i-1]):
    #       pred = i
    #   pred_tag[pred,ys[j]] += 1
    #   j += 1

    for i in range(len(xs)):
      pred = torch.argmax(probs[i])
      pred = int(pred)
      pred_tag[pred, ys[i]] += 1


for i in range(len(tag2id)):
  row_sum = 0
  column_sum = 0
  for j in range(len(tag2id)):
    # print(pred_tag[i,j])
    row_sum += pred_tag[i,j]
  for j in range(len(tag2id)):
    column_sum += pred_tag[j,i]

  if(row_sum != 0):
    precision[unique_tags[i]] = pred_tag[i,i]*1.0/row_sum
  if(column_sum != 0):
    recall[unique_tags[i]] = pred_tag[i,i]*1.0/column_sum
  f1[unique_tags[i]] = 2*precision[unique_tags[i]]*recall[unique_tags[i]]/(precision[unique_tags[i]]+recall[unique_tags[i]])
  f0_5[unique_tags[i]] = 1.25*precision[unique_tags[i]]*recall[unique_tags[i]]/(0.25*precision[unique_tags[i]]+recall[unique_tags[i]])
  f2[unique_tags[i]] = 5*precision[unique_tags[i]]*recall[unique_tags[i]]/(4*precision[unique_tags[i]]+recall[unique_tags[i]])

print(pred_tag)

print(f"Test loss : {testing_loss/len(test_x)}")
print(f"Precision : {precision}")
print(f"Recall : {recall}")
print(f"F1-score : {f1}")
print(f"F0.5-score : {f0_5}")
print(f"F2-score : {f2}")
# Out:
# [[ 9914     9     0     2   170     0    29     7     1   163     0     0]
#  [    2 16326   491   374     5     0    43     0    41     2    17    73]
#  [    1   352  4617    76    15     0   172     0    29     0     3     8]
#  [    1   647   123 16377     8     0    38     0    38     1     1    19]
#  [   39    32     4    21  8871     0   216     2   430    20     0     1]
#  [    0     1     1     1     0 15504     0     0     0     0     0     1]
#  [    5   143   240    46   153     0  4781     3    55     2     3     7]
#  [    2     0     0     0     8     0     4  3313     0     0     0     0]
#  [    0    32     7    10   361     0    70     0  2847     0     0     4]
#  [  149     6     1     1    39     0     0     0     2  7165     0     0]
#  [    0   113     5     8     0     0     4     0     2     0   463     1]
#  [    0    31     3     1     0     1     0     1     1     0     0    10]]
# Test loss : 0.21329085923997224
# Precision : {'DET': 0.9629917435648373, 'NOUN': 0.9396799815816738, 'ADJ': 0.8755926417599089, 'VERB': 0.949226221526691, 'ADP': 0.9206102117061021, '.': 0.9997420686097498, 'ADV': 0.8791835233541744, 'CONJ': 0.9957920048091373, 'PRT': 0.8546982888021615, 'PRON': 0.973108787179139, 'NUM': 0.7768456375838926, 'X': 0.20833333333333334}
# Recall : {'DET': 0.9803223573618115, 'NOUN': 0.922789961564549, 'ADJ': 0.8406773488710853, 'VERB': 0.9680794467104097, 'ADP': 0.9211838006230529, '.': 0.999935504675911, 'ADV': 0.8924771327235393, 'CONJ': 0.9960914010823813, 'PRT': 0.82617527568195, 'PRON': 0.9744322045423637, 'NUM': 0.9507186858316222, 'X': 0.08064516129032258}
# F1-score : {'DET': 0.9715797726381811, 'NOUN': 0.9311583870415786, 'ADJ': 0.8577798420808175, 'VERB': 0.9585601404741001, 'ADP': 0.9208969168483339, '.': 0.9998387772869441, 'ADV': 0.8857804539138491, 'CONJ': 0.995941680444912, 'PRT': 0.8401947764497564, 'PRON': 0.9737700462082087, 'NUM': 0.8550323176361956, 'X': 0.11627906976744184}
# F0.5-score : {'DET': 0.9664086717485817, 'NOUN': 0.9362526953250448, 'ADJ': 0.868379476376768, 'VERB': 0.9529378905840868, 'ADP': 0.9207248723377757, '.': 0.9997807498355625, 'ADV': 0.8818104688479841, 'CONJ': 0.9958518696645425, 'PRT': 0.8488372093023255, 'PRON': 0.9733731829914415, 'NUM': 0.8063392546151167, 'X': 0.15822784810126586}
# F2-score : {'DET': 0.9768065107296983, 'NOUN': 0.9261192167184771, 'ADJ': 0.8474358503726, 'VERB': 0.9642491256579644, 'ADP': 0.9210690256665836, '.': 0.9998968114745642, 'ADV': 0.8897863470557581, 'CONJ': 0.9960315074258915, 'PRT': 0.831726555652936, 'PRON': 0.974167233174711, 'NUM': 0.9099842767295598, 'X': 0.09191176470588236}

# %%
# Heatmap

seaborn.heatmap(pred_tag)
# Out:
# <Axes: >

# %%
# Macro scores

macro_precision = 0.0
NA_precisions = 0
for i in precision:
  if(precision[i] == "NA"):
    NA_precisions += 1
  else:
    macro_precision += precision[i]
macro_precision /= (len(tag2id) - NA_precisions)

macro_recall = 0.0
NA_recalls = 0
for i in recall:
  if(recall[i] == "NA"):
    NA_recalls += 1
  else:
    macro_recall += recall[i]
macro_recall /= (len(tag2id) - NA_recalls)

macro_f1 = 2*macro_precision*macro_recall/(macro_precision+macro_recall)
macro_f0_5 = 1.25*macro_precision*macro_recall/(0.25*macro_precision+macro_recall)
macro_f2 = 5*macro_precision*macro_recall/(4*macro_precision+macro_recall)

print(f"Macro precision: {macro_precision}")
print(f"Macro recall: {macro_recall}")
print(f"Macro f1 score: {macro_f1}")
print(f"Macro f0.5 score: {macro_f0_5}")
print(f"Macro f2 score: {macro_f2}")
# Out:
# Macro precision: 0.8613170369842336
# Macro recall: 0.86279402341325
# Macro f1 score: 0.8620548975570976
# Macro f0.5 score: 0.8616120295873914
# Macro f2 score: 0.862498221028574

# %%
# Micro scores

den = 0.0
for i in range(len(tag2id)):
  for j in range(len(tag2id)):
    den += pred_tag[i][j]

micro_precision = 0.0
for i in range(len(tag2id)):
  micro_precision += pred_tag[i,i]
micro_precision /= den

micro_recall = 0.0
for i in range(len(tag2id)):
  micro_recall += pred_tag[i,i]
micro_recall /= den

micro_f1 = 2*micro_precision*micro_recall/(micro_precision+micro_recall)
micro_f0_5 = 1.25*micro_precision*micro_recall/(0.25*micro_precision+micro_recall)
micro_f2 = 5*micro_precision*micro_recall/(4*micro_precision+micro_recall)

print(f"Micro precision: {micro_precision}")
print(f"Micro recall: {micro_recall}")
print(f"Micro f1 score: {micro_f1}")
print(f"Micro f0.5 score: {micro_f0_5}")
print(f"Micro f2 score: {micro_f2}")
# Out:
# Micro precision: 0.944950860208294
# Micro recall: 0.944950860208294
# Micro f1 score: 0.944950860208294
# Micro f0.5 score: 0.944950860208294
# Micro f2 score: 0.944950860208294

# %% [markdown]
# # Inference

# %%
# # id = word2id["work"]

# for i in range(len(words)):
#   for j in range(len(words[i])):
#     if(words[i][j] == "that"):
#       print(tags[i][j])

# %%
# Training example
input = ' '.join(words[0])

# %%
def infer(input):
  # Use for inference
  input_tokens = word_tokenize(input.lower())

  # Use for training example
  # input_tokens = input.lower().strip().split()

  input_nums = []

  for i in range(len(input_tokens)):
    if(input_tokens[i] not in word2id):
      input_nums.append(11)
    else:
      input_nums.append(word2id[input_tokens[i]])

  input_tensor = torch.from_numpy(np.array(input_nums)).to(device)

  model.eval()
  with torch.no_grad():
    model.hidden_state = model.hidden_state_initialize()

    probs = model(input_tensor)

    # for p in probs:
    #   pred = 0
    #   for i in range(1,len(tag2id)):
    #     if(p[i] > p[i-1]):
    #       pred = i
    #   print(unique_tags[pred])

    for i in range(len(input_tensor)):
      pred = torch.argmax(probs[i])
      pred = int(pred)
      print(unique_tags[pred])

# %%
# Inference
input = "Can you open this can?"

# %%
infer(input)
# Out:
# VERB
# PRON
# VERB
# DET
# VERB
# .
